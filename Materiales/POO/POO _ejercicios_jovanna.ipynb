# %% [markdown]
# # Agenda
# Realizar una clase que administre una `agenda`. Se debe almacenar para cada contacto el nombre, el teléfono y el email. Además deberá mostrar un menú con las siguientes opciones:
#
# - Añadir contacto
# - Lista de contactos
# - Buscar contacto
# - Editar contacto
# - Cerrar agenda

# %%
class agenda:
    def __init__(self):
        self.contactos = []

#pero y si solo quiero agregar nombre apellidos y telefono y editar luego?
    def agregar_contacto(self, nombre:str, apellidos:str, telefono:str, email:str, direccion:str, ocupacion:str):
        contacto = contacto(nombre, apellidos, telefono, email, direccion, ocupacion)
        self.contactos.append(contacto)
        print(f"Contacto {nombre}, {apellidos} agregado")

    def lista_contactos(self):
        if self.contactos:
            print("Lista de contactos:")
            for contacto in self.contactos:
                print(contacto)
        else:
            print("No hay contactos guardados")

    def busca_contacto(self, nombre, apellidos):
        for contacto in self.contactos:
            if contacto.nombre == nombre & contacto.apellidos == apellidos:
                print(contacto) 
                return contacto
        print(f"Contacto {nombre} inexistente.")
        return None

    def edita_contacto(self, nombre, apellidos):
        contacto = self.busca_contacto(nombre, apellidos)
        if contacto:
            nuevo_nombre = input("Nuevo nombre: ")
            nuevos_apellidos = input("Nuevos apellidos: ")
            nueva_ocupacion = input("Nueva ocupación: ")
            nuevo_telefono = input("Nuevo teléfono: ")
            nuevo_email = input("Nuevo email: ")
            nueva_direccion = input("Nueva direccion: ")

            if nuevo_nombre:
                contacto.nombre = nuevo_nombre
            if nuevos_apellidos:
                contacto.apellidos = nuevos_apellidos
            if nueva_ocupacion:
                contacto.ocupacion = nueva_ocupacion
            if nuevo_telefono:
                contacto.telefono = nuevo_telefono
            if nuevo_email:
                contacto.email = nuevo_email
            if nueva_direccion:
                contacto.direccion = nueva_direccion
            print(f"Contacto {nombre} actualizado")
        else:
            print(f"El contacto {nombre} no se encontró")
    
    def cerrar_agenda(self):
        print("Cerrando agenda...")
        exit()

    def contacto_existente(self, nombre, apellidos):
        for contacto in self.contactos:
            if contacto.nombre == nombre and contacto.apellidos == apellidos:
                print("Ya existe un contacto con este nombre y apellidos")
                return contacto
            
        return False
            #y que de aqui me lleve a edtitar ese contacto

# %%
agenda.agregar_contacto('1','Daniela','Vidal Angulo','631456789','daniela.vidal@gamma.com', 'por ahi del numero 4, 28005', 'rascarse la panza')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 agenda.agregar_contacto('1','Daniela','Vidal Angulo','631456789','daniela.vidal@gamma.com', 'por ahi del numero 4, 28005', 'rascarse la panza')
#
# Cell In[2], line 7, in agenda.agregar_contacto(self, nombre, apellidos, telefono, email, direccion, ocupacion)
#       6 def agregar_contacto(self, nombre:str, apellidos:str, telefono:str, email:str, direccion:str, ocupacion:str):
# ----> 7     contacto = contacto(nombre, apellidos, telefono, email, direccion, ocupacion)
#       8     self.contactos.append(contacto)
#       9     print(f"Contacto {nombre}, {apellidos} agregado")
#
# UnboundLocalError: local variable 'contacto' referenced before assignment

# %% [markdown]
# # Banco
# En un banco tienen clientes que pueden hacer **depósitos** y **extracciones** de dinero. El banco requiere también al final del día calcular la cantidad de dinero que se ha depositado.
#
# Se deberán crear **dos clases**, la clase `cliente` y la clase `banco`. La clase **cliente** tendrá los atributos `nombre` y `cantidad` y los métodos `__init__`, `depositar`, `extraer`, `mostrar_total`.
#
# La clase **banco** tendrá como atributos 3 objetos de la clase cliente y los métodos `__init__`, `operar` y `deposito_total`.

# %% [markdown]
# # Cuentas ahorro
# Desarrollar un programa que conste de una **clase padre** `Cuenta` y **dos subclases** `PlazoFijo` y `CajaAhorro`. Definir los **atributos** `titular` y `cantidad` y un **método** para `imprimir` los datos en la clase Cuenta. La **clase CajaAhorro** tendrá un método para heredar los datos y uno para mostrar la información.
#
# La **clase PlazoFijo** tendrá dos atributos propios, `plazo` e `interés`. Tendrá un método para obtener el importe del interés (cantidad*interés/100) y otro método para mostrar la información, datos del titular plazo, interés y total de interés.
#
# Crear al menos un objeto de cada subclase.
