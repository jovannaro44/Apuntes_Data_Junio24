# %%
# %pip install selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (4.24.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from selenium) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from trio~=0.17->selenium) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (4.0.2)
# Requirement already satisfied: requests in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from webdriver-manager) (1.0.1)
# Requirement already satisfied: packaging in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from webdriver-manager) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from requests->webdriver-manager) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from requests->webdriver-manager) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from requests->webdriver-manager) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages (from requests->webdriver-manager) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager # Se encarga de descargar el driver de chrome y de mantenerlo actualizado
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])
chrome_options.add_experimental_option('useAutomationExtension', False)
chrome_options.add_argument("--disable-infobars") #desactivar los de chrome is being used by a test software

# %%
import time
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By # By es para buscar por tag, clase, id...
import requests as req
from bs4 import BeautifulSoup as bs
import os
import selenium.webdriver.common.keys 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
import random
from dotenv import load_dotenv
from selenium.webdriver.common.action_chains import ActionChains

# %%
driver = webdriver.Chrome()

form_url = "https://docs.google.com/forms/d/e/1FAIpQLSej_M_4bAB4m_L8KcFoGPWWKBYrkZ9TEktwtWQ-7j2pIJNEkA/viewform?hr_submission=ChkIiYed2Z0UEhAI1J22_vUUEgcIj9X-6_sSEAE"
driver.get(form_url)

time.sleep(3)

# %%
#cargar variable .env
load_dotenv()

usuario = os.getenv('user_gamma')
clave = os.getenv('password_gamma')
link = os.getenv('link_video')

# %%
#log in
email = driver.find_element(By.XPATH, '//*[@id="identifierId"]')
email.send_keys(usuario) 
time.sleep(3)
email.send_keys(Keys.RETURN) 
time.sleep(5)

# %%
password = driver.find_element(By.XPATH, '//*[@id="password"]/div[1]/div/div[1]/input')
password.send_keys(clave) 
time.sleep(2)
password.send_keys(Keys.RETURN)

time.sleep(4)

# %%
#time for scrolling set up
scroll_pause = 0.2  
scroll_height = 300 
last_height = driver.execute_script("return document.body.scrollHeight")

# %%
#scroll to find record
record = driver.find_element(By.XPATH, '//*[@id="mG61Hd"]/div[2]/div/div[2]/div[1]/div[1]')
driver.execute_script("arguments[0].scrollIntoView();", record)

# %%
#click on record
record_box = driver.find_element(By.CSS_SELECTOR, '[jscontroller="EcW08c"]')
record_box.click()

# %%
#scroll to find q 1
question = driver.find_element(By.XPATH, '//*[@id="i21"]/div[3]/div')
driver.execute_script("arguments[0].scrollIntoView();", question)

# %%
#clcik on right answer for q1
question.click()

# %%
answer1 = []
youtube =  driver.find_element(By.CSS_SELECTOR, "iframe.GonXTb")
driver.execute_script("arguments[0].scrollIntoView();", youtube)
youtube.click()
time.sleep(4)
youtube.click()

# %%
link_youtube = youtube.get_attribute('src')
answer1.append(link_youtube)
print(answer1)

time.sleep(3)
# Out:
# ['https://www.youtube.com/embed/2_x3qsBJndo?rel=0&embed_config=%7B%22enc%22%3A%22AQ2SFqC_YESru9EYXo6bpoyKxKsADeZrB8HStmYDAnrdIAaNXZjS3nJWir9lcjwFPIhCciaT1RW8HTEYaMcdsDLtF_8HyiDtxfZwtAuHcB8Pbs8dUdk0udtw26s8g8gjQjvzzA9HXP-oTZ_c1NTJ8AqxjD_A7m4jB-cpabj7agBbR8M3%22%7D&errorlinks=1&rct=CpcBAQ2SFqC_S832yGS1YEHRFWWRxKKTM0_N7y2AeDKmXwnR0lVbZQjHuK4VA3pgjW2iBaXxbgOEAR2Z56qbbiIEzQR3Wrh3xBkqaB7wIYaP0mPDb9xZWQO8bmHIau2ccrhYn77sMbNBYtMbaJa9JDwZ2VVdUTW2iDZUTHBWlDbDD2S5hr_OL9-oR81_iSaSrJcywj3YcvwAkA%3D%3D']

# %%
string_answer1 =  answer1[0]
print(string_answer1)
# Out:
# https://www.youtube.com/embed/2_x3qsBJndo?rel=0&embed_config=%7B%22enc%22%3A%22AQ2SFqC_YESru9EYXo6bpoyKxKsADeZrB8HStmYDAnrdIAaNXZjS3nJWir9lcjwFPIhCciaT1RW8HTEYaMcdsDLtF_8HyiDtxfZwtAuHcB8Pbs8dUdk0udtw26s8g8gjQjvzzA9HXP-oTZ_c1NTJ8AqxjD_A7m4jB-cpabj7agBbR8M3%22%7D&errorlinks=1&rct=CpcBAQ2SFqC_S832yGS1YEHRFWWRxKKTM0_N7y2AeDKmXwnR0lVbZQjHuK4VA3pgjW2iBaXxbgOEAR2Z56qbbiIEzQR3Wrh3xBkqaB7wIYaP0mPDb9xZWQO8bmHIau2ccrhYn77sMbNBYtMbaJa9JDwZ2VVdUTW2iDZUTHBWlDbDD2S5hr_OL9-oR81_iSaSrJcywj3YcvwAkA%3D%3D

# %%
driver.switch_to.default_content()

# %%
link_video = "https://www.youtube.com/6987aa1a-4b28-4ed0-a526-eb1555ecf35a"
wait = WebDriverWait(driver, 10)
typein1 = wait.until(EC.visibility_of_element_located((By.XPATH, '//*[@id="mG61Hd"]/div[2]/div/div[2]/div[4]/div/div/div[2]/div/div[1]/div/div[1]/input'))) 

typein1.click()
time.sleep(2)

if typein1.is_displayed() and typein1.is_enabled():
    for character in link_video:
        typein1.send_keys(character)
        time.sleep(random.uniform(0.3, 0.75))
else:
    print("I cant type")


print('typed')
# Out:
# typed

# %%
image_url = driver.find_element(By.CSS_SELECTOR, '#i28 > span > a')
image_url.click()

# %%
driver.switch_to.window(driver.window_handles[1])
time.sleep(1)

# %%
cookies_deny = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//button[text()='Aceptar solo las esenciales']")))
cookies_deny.click()

# %%
related_img = driver.find_element(By.CSS_SELECTOR, '#app > div > div > div:nth-child(4) > div > div.m3xjc.NZxG4.n6mLh.BOC6f > div > div:nth-child(2)')
driver.execute_script("arguments[0].scrollIntoView(true);", related_img)

# %%
list_img = []

image_element = driver.find_element(By.CSS_SELECTOR, 'img.I7OuT.DVW3V.L1BOa')
driver.execute_script("arguments[0].scrollIntoView(true);", image_element)

time.sleep(1.5)

src = image_element.get_attribute('src')
list_img.append(src)

# %%
image1 = driver.find_element(By.CSS_SELECTOR, 'img.I7OuT.DVW3V.L1BOa')
src1 = image_element.get_attribute('src')
list_img.append(src1)

# %%
image2 = driver.find_element(By.CSS_SELECTOR, 'img[data-testid="photo-grid-masonry-img"]')
src2 = image_element.get_attribute('src')
list_img.append(src2)

# %%
image3 = driver.find_element(By.CSS_SELECTOR, 'img[data-testid="photo-grid-masonry-img"]')
src3 = image_element.get_attribute('src')
list_img.append(src3)

# %%
image4 = driver.find_element(By.CSS_SELECTOR, 'img[data-testid="photo-grid-masonry-img"]')
src4 = image_element.get_attribute('src')
list_img.append(src4)

# %%
image5 = driver.find_element(By.CSS_SELECTOR, 'img[data-testid="photo-grid-masonry-img"]')
src5 = image_element.get_attribute('src')
list_img.append(src5)
string_answer_6l = ", ".join(list_img)

# %%
#get pics thru blocks
left_block = driver.find_element(By.CSS_SELECTOR,'#app > div > div > div:nth-child(4) > div > div.m3xjc.NZxG4.n6mLh.BOC6f > div > div:nth-child(2) > div > div > div.LYMM9 > div:nth-child(1)')
right_block = driver.find_element(By.CSS_SELECTOR,'#app > div > div > div:nth-child(4) > div > div.m3xjc.NZxG4.n6mLh.BOC6f > div > div:nth-child(2) > div > div > div.LYMM9 > div:nth-child(2)')

pic_left_block = left_block.find_elements(By.CLASS_NAME, 'zNNw1')
pic_right_block = right_block.find_elements(By.CLASS_NAME, 'zNNw1')

#extract all urls
urls_left = [foto.get_attribute('href') for foto in pic_left_block]
urls_right = [foto.get_attribute('href') for foto in pic_right_block]

#combine both into a list and make it a string
all_relaterd_pics = urls_right + urls_left
string_answer_urls = '; '.join([f'foto {i+1}: {url}' for i, url in enumerate(all_relaterd_pics)])

print(string_answer_urls)
# Out:
# foto 1: https://unsplash.com/es/fotos/el-sol-se-esta-poniendo-sobre-una-cadena-montanosa--RlktmDy3Ec; foto 2: https://unsplash.com/es/fotos/una-vista-de-una-cadena-montanosa-desde-un-punto-de-vista-alto-_iheCDGyWS8; foto 3: https://unsplash.com/es/fotos/una-vista-aerea-de-una-formacion-rocosa-en-el-desierto-epQdtCvBrc4; foto 4: https://unsplash.com/es/fotos/una-persona-de-pie-en-la-cima-de-una-montana-aFkQwFefxGE; foto 5: https://unsplash.com/es/fotos/una-gran-formacion-rocosa-en-medio-de-un-desierto-bRRy9ucK1rY; foto 6: https://unsplash.com/es/fotos/una-colina-cubierta-de-hierba-con-montanas-al-fondo-Jgl1WK2e38U; foto 7: https://unsplash.com/es/fotos/una-gran-formacion-rocosa-con-un-pequeno-agujero-en-el-medio-de-ella-_jfejQo2tZw; foto 8: https://unsplash.com/es/fotos/una-vista-de-las-montanas-desde-un-punto-de-vista-alto-eU1P78Rge-k; foto 9: https://unsplash.com/es/fotos/una-vista-aerea-de-un-desierto-al-atardecer-YeLs9lJDx9M; foto 10: https://unsplash.com/es/fotos/un-hombre-sentado-en-la-cima-de-una-montana-junto-a-un-exuberante-campo-verde-7DSn2ECqZ50; foto 11: https://unsplash.com/es/fotos/una-persona-caminando-por-un-canon-en-el-desierto-9633dHhioC8; foto 12: https://unsplash.com/es/fotos/un-hombre-sentado-en-una-roca-en-el-desierto-ud9NlvvEzUI; foto 13: https://unsplash.com/es/fotos/una-vista-aerea-de-un-desierto-con-rocas-y-arena-XDtzu1D2P8c; foto 14: https://unsplash.com/es/fotos/una-mujer-parada-en-medio-de-un-desierto-JZerhwPHiBI; foto 15: https://unsplash.com/es/fotos/un-paisaje-desertico-con-rocas-y-arena-THlO6Mkf5uI; foto 16: https://unsplash.com/es/fotos/una-persona-mirando-desde-una-cueva-en-el-desierto-9bE0LlCrX2M; foto 17: https://unsplash.com/es/fotos/una-persona-parada-en-la-entrada-de-una-cueva-kXbit_yx8t4; foto 18: https://unsplash.com/es/fotos/una-vista-aerea-de-un-desierto-con-rocas-y-arena-39n8YVSn0d4; foto 19: https://unsplash.com/es/fotos/una-formacion-rocosa-en-el-desierto-con-montanas-al-fondo-fYTVHcpak2g; foto 20: https://unsplash.com/es/fotos/un-hombre-parado-en-la-cima-de-una-colina-arenosa-sP5ZW-JDIfI

# %%
#switch window back to google forms
driver.switch_to.window(driver.window_handles[0])

# %%
input2 = driver.find_element(By.CSS_SELECTOR,'#mG61Hd > div.RH5hzf.RLS9Fe > div > div.o3Dpx > div:nth-child(6) > div > div > div.AgroKb > div > div.aCsJod.oJeWuf > div > div.Xb9hP > input')
driver.execute_script("arguments[0].scrollIntoView(true);", input2)
time.sleep(3)
input2.click()
input2.send_keys(string_answer_urls)

# %%
#finding and typing answer to last question (6urls)
input3 = driver.find_element(By.CSS_SELECTOR, '#mG61Hd > div.RH5hzf.RLS9Fe > div > div.o3Dpx > div:nth-child(7) > div > div > div.AgroKb > div > div.RpC4Ne.oJeWuf > div.Pc9Gce.Wic03c > textarea') 
driver.execute_script("arguments[0].scrollIntoView(true);", input3)
time.sleep(3)
input3.click()
input3.send_keys(string_answer_6l)

# %%
#click next
next_button = driver.find_element(By.CSS_SELECTOR, '#mG61Hd > div.RH5hzf.RLS9Fe > div > div.ThHDze > div.DE3NNc.CekdCb > div.lRwqcd > div > span > span')
next_button.click()

# %%
#on new page scroll down a bit
driver.execute_script("window.scrollBy(0, 320);")

# %%
#page 2 find and click answer (5)
p2_q1 = driver.find_element(By.CSS_SELECTOR, '#mG61Hd > div.RH5hzf.RLS9Fe > div > div.o3Dpx > div:nth-child(2) > div > div > div.PY6Xd > div > span > div > label:nth-child(6) > div.eRqjfd > div > div > div.vd3tt > div')
p2_q1.click()

# %%
labels_to_click = [
    '1, response for 1',
    '1, response for 2',
    '1, response for 3',
    '2, response for 3',
    '3, response for 3'
    
]

for label in labels_to_click:
    try:
        # finding element
        click_element = driver.find_element(By.CSS_SELECTOR, f'[aria-label="{label}"]')
        
        # Usar ActionChains si es necesario
        action = ActionChains(driver)
        action.move_to_element(click_element).click().perform()
        
        # Esperar un momento para asegurarte que la acción se completa
        time.sleep(2)
        
    except Exception as e:
        print(f"couldnt find'{label}': {e}")

# %%
#scroll down another bit
driver.execute_script("window.scrollBy(0, 450);")

# %%
drop_menu = driver.find_element(By.CSS_SELECTOR, '#mG61Hd > div.RH5hzf.RLS9Fe > div > div.o3Dpx > div:nth-child(4) > div > div > div.vQES8d > div > div:nth-child(1) > div.e2CuFe.eU809d')
driver.execute_script("arguments[0].scrollIntoView(true);", drop_menu)
drop_menu.click()

# %%
#finding and entering dropdown menu's shadow
shadow_host = driver.find_element(By.CSS_SELECTOR, '#mG61Hd > div.RH5hzf.RLS9Fe > div > div.o3Dpx > div:nth-child(4) > div > div > div.vQES8d > div > div.OA0qNb.ncFHed.QXL7Te')
shadow_root = driver.execute_script("return arguments[0].shadowRoot", shadow_host)

# %%
#clicking on si
si_element = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="mG61Hd"]/div[2]/div/div[2]/div[4]/div/div/div[2]/div/div[2]/div[3]/span')))
si_element.click()

# %%
# Click the "Add file" element
add_file = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//span[text()='Add file']")))
add_file.click()

# %%
iframe_drive = driver.find_element(By.XPATH, '/html/body/iframe')

# %%
driver.switch_to.frame(iframe_drive)

# %%
#aqui me quede intendado encontrar el segundo frame para hacer click en My Drive

# %%
iframe_child = driver.find_element(By.CSS_SELECTOR, )
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[924], line 1
# ----> 1 iframe_child = driver.find_element(By.CSS_SELECTOR, '[ng-non-bindable="" frameborder="0" hspace="0" marginheight="0" marginwidth="0" scrolling="no" tabindex="0" vspace="0" width="100%" height="100%" allow="camera id="k2szgt6sfltg" name="k2szgt6sfltg"]')
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# InvalidSelectorException: Message: invalid selector
# from javascript error: {"status":32,"value":"An invalid or illegal selector was specified"}
#   (Session info: chrome=129.0.6668.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalid-selector-exception
# Stacktrace:
# 0   chromedriver                        0x0000000107df1d68 chromedriver + 4996456
# 1   chromedriver                        0x0000000107de962a chromedriver + 4961834
# 2   chromedriver                        0x000000010798cd10 chromedriver + 388368
# 3   chromedriver                        0x0000000107992ec9 chromedriver + 413385
# 4   chromedriver                        0x000000010799484f chromedriver + 419919
# 5   chromedriver                        0x00000001079948fc chromedriver + 420092
# 6   chromedriver                        0x00000001079d8fa9 chromedriver + 700329
# 7   chromedriver                        0x00000001079d93f1 chromedriver + 701425
# 8   chromedriver                        0x0000000107a1e464 chromedriver + 984164
# 9   chromedriver                        0x00000001079fd9dd chromedriver + 850397
# 10  chromedriver                        0x0000000107a1ba00 chromedriver + 973312
# 11  chromedriver                        0x00000001079fd753 chromedriver + 849747
# 12  chromedriver                        0x00000001079cc635 chromedriver + 648757
# 13  chromedriver                        0x00000001079cce5e chromedriver + 650846
# 14  chromedriver                        0x0000000107db8050 chromedriver + 4759632
# 15  chromedriver                        0x0000000107dbcf68 chromedriver + 4779880
# 16  chromedriver                        0x0000000107dbd635 chromedriver + 4781621
# 17  chromedriver                        0x0000000107d9aaf9 chromedriver + 4639481
# 18  chromedriver                        0x0000000107dbd929 chromedriver + 4782377
# 19  chromedriver                        0x0000000107d8c094 chromedriver + 4579476
# 20  chromedriver                        0x0000000107dd9a58 chromedriver + 4897368
# 21  chromedriver                        0x0000000107dd9c53 chromedriver + 4897875
# 22  chromedriver                        0x0000000107de922e chromedriver + 4960814
# 23  libsystem_pthread.dylib             0x00007ff80d004253 _pthread_start + 99
# 24  libsystem_pthread.dylib             0x00007ff80cfffbef thread_start + 15

# %%
driver.switch_to.frame(iframe_child)

# %%
shadow_host1 = driver.find_element(By.XPATH,'//*[@id="1"]')
shadow_root1 = driver.execute_script("return arguments[0].shadowRoot", shadow_host1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[927], line 1
# ----> 1 shadow_host1 = driver.find_element(By.XPATH,'//*[@id="1"]')
#       2 shadow_root1 = driver.execute_script("return arguments[0].shadowRoot", shadow_host1)
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="1"]"}
#   (Session info: chrome=129.0.6668.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000107df1d68 chromedriver + 4996456
# 1   chromedriver                        0x0000000107de962a chromedriver + 4961834
# 2   chromedriver                        0x000000010798cd10 chromedriver + 388368
# 3   chromedriver                        0x00000001079d930f chromedriver + 701199
# 4   chromedriver                        0x00000001079d93f1 chromedriver + 701425
# 5   chromedriver                        0x0000000107a1e464 chromedriver + 984164
# 6   chromedriver                        0x00000001079fd9dd chromedriver + 850397
# 7   chromedriver                        0x0000000107a1ba00 chromedriver + 973312
# 8   chromedriver                        0x00000001079fd753 chromedriver + 849747
# 9   chromedriver                        0x00000001079cc635 chromedriver + 648757
# 10  chromedriver                        0x00000001079cce5e chromedriver + 650846
# 11  chromedriver                        0x0000000107db8050 chromedriver + 4759632
# 12  chromedriver                        0x0000000107dbcf68 chromedriver + 4779880
# 13  chromedriver                        0x0000000107dbd635 chromedriver + 4781621
# 14  chromedriver                        0x0000000107d9aaf9 chromedriver + 4639481
# 15  chromedriver                        0x0000000107dbd929 chromedriver + 4782377
# 16  chromedriver                        0x0000000107d8c094 chromedriver + 4579476
# 17  chromedriver                        0x0000000107dd9a58 chromedriver + 4897368
# 18  chromedriver                        0x0000000107dd9c53 chromedriver + 4897875
# 19  chromedriver                        0x0000000107de922e chromedriver + 4960814
# 20  libsystem_pthread.dylib             0x00007ff80d004253 _pthread_start + 99
# 21  libsystem_pthread.dylib             0x00007ff80cfffbef thread_start + 15

# %%
my_drive_button = driver.find_element(By.CSS_SELECTOR, '[jsaction="click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e"]')
my_drive_button.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[925], line 1
# ----> 1 my_drive_button = driver.find_element(By.CSS_SELECTOR, '[jsaction="click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e"]')
#       2 my_drive_button.click()
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[jsaction="click:cOuCgd; mousedown:UX7yZ; mouseup:lbsD7e; mouseenter:tfO1Yc; mouseleave:JywGue; touchstart:p6p2H; touchmove:FwuNnf; touchend:yfqBxc; touchcancel:JMtRjd; focus:AHmuwe; blur:O22p3e"]"}
#   (Session info: chrome=129.0.6668.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000107df1d68 chromedriver + 4996456
# 1   chromedriver                        0x0000000107de962a chromedriver + 4961834
# 2   chromedriver                        0x000000010798cd10 chromedriver + 388368
# 3   chromedriver                        0x00000001079d930f chromedriver + 701199
# 4   chromedriver                        0x00000001079d93f1 chromedriver + 701425
# 5   chromedriver                        0x0000000107a1e464 chromedriver + 984164
# 6   chromedriver                        0x00000001079fd9dd chromedriver + 850397
# 7   chromedriver                        0x0000000107a1ba00 chromedriver + 973312
# 8   chromedriver                        0x00000001079fd753 chromedriver + 849747
# 9   chromedriver                        0x00000001079cc635 chromedriver + 648757
# 10  chromedriver                        0x00000001079cce5e chromedriver + 650846
# 11  chromedriver                        0x0000000107db8050 chromedriver + 4759632
# 12  chromedriver                        0x0000000107dbcf68 chromedriver + 4779880
# 13  chromedriver                        0x0000000107dbd635 chromedriver + 4781621
# 14  chromedriver                        0x0000000107d9aaf9 chromedriver + 4639481
# 15  chromedriver                        0x0000000107dbd929 chromedriver + 4782377
# 16  chromedriver                        0x0000000107d8c094 chromedriver + 4579476
# 17  chromedriver                        0x0000000107dd9a58 chromedriver + 4897368
# 18  chromedriver                        0x0000000107dd9c53 chromedriver + 4897875
# 19  chromedriver                        0x0000000107de922e chromedriver + 4960814
# 20  libsystem_pthread.dylib             0x00007ff80d004253 _pthread_start + 99
# 21  libsystem_pthread.dylib             0x00007ff80cfffbef thread_start + 15

# %%
try:
    

    #find n click search box
    search_box = wait.until(EC.visibility_of_element_located((By.XPATH, '//input[@aria-label="Search in Drive or paste URL"]')))
    search_box.click()

    #type in the file name
    search_box.send_keys('google_formulario_jovanna.ipynb')

    

except Exception as e:
    print(f"An error occurred: {e}")

finally:

   # Switch back to the main content
    driver.switch_to.default_content()
# Out:
# An error occurred: Message:
# Stacktrace:
# 0   chromedriver                        0x000000010da3dd68 chromedriver + 4996456
# 1   chromedriver                        0x000000010da3562a chromedriver + 4961834
# 2   chromedriver                        0x000000010d5d8d10 chromedriver + 388368
# 3   chromedriver                        0x000000010d62530f chromedriver + 701199
# 4   chromedriver                        0x000000010d6253f1 chromedriver + 701425
# 5   chromedriver                        0x000000010d66a464 chromedriver + 984164
# 6   chromedriver                        0x000000010d6499dd chromedriver + 850397
# 7   chromedriver                        0x000000010d667a00 chromedriver + 973312
# 8   chromedriver                        0x000000010d649753 chromedriver + 849747
# 9   chromedriver                        0x000000010d618635 chromedriver + 648757
# 10  chromedriver                        0x000000010d618e5e chromedriver + 650846
# 11  chromedriver                        0x000000010da04050 chromedriver + 4759632
# 12  chromedriver                        0x000000010da08f68 chromedriver + 4779880
# 13  chromedriver                        0x000000010da09635 chromedriver + 4781621
# 14  chromedriver                        0x000000010d9e6af9 chromedriver + 4639481
# 15  chromedriver                        0x000000010da09929 chromedriver + 4782377
# 16  chromedriver                        0x000000010d9d8094 chromedriver + 4579476
# 17  chromedriver                        0x000000010da25a58 chromedriver + 4897368
# 18  chromedriver                        0x000000010da25c53 chromedriver + 4897875
# 19  chromedriver                        0x000000010da3522e chromedriver + 4960814
# 20  libsystem_pthread.dylib             0x00007ff80d004253 _pthread_start + 99
# 21  libsystem_pthread.dylib             0x00007ff80cfffbef thread_start + 15

# %%
child_iframe_drive = driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/div/iframe')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[710], line 1
# ----> 1 child_iframe_drive = driver.find_element(By.XPATH, '/html/body/div[3]/div[2]/div/iframe')
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[3]/div[2]/div/iframe"}
#   (Session info: chrome=129.0.6668.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x000000010b12cd68 chromedriver + 4996456
# 1   chromedriver                        0x000000010b12462a chromedriver + 4961834
# 2   chromedriver                        0x000000010acc7d10 chromedriver + 388368
# 3   chromedriver                        0x000000010ad1430f chromedriver + 701199
# 4   chromedriver                        0x000000010ad143f1 chromedriver + 701425
# 5   chromedriver                        0x000000010ad59464 chromedriver + 984164
# 6   chromedriver                        0x000000010ad389dd chromedriver + 850397
# 7   chromedriver                        0x000000010ad56a00 chromedriver + 973312
# 8   chromedriver                        0x000000010ad38753 chromedriver + 849747
# 9   chromedriver                        0x000000010ad07635 chromedriver + 648757
# 10  chromedriver                        0x000000010ad07e5e chromedriver + 650846
# 11  chromedriver                        0x000000010b0f3050 chromedriver + 4759632
# 12  chromedriver                        0x000000010b0f7f68 chromedriver + 4779880
# 13  chromedriver                        0x000000010b0f8635 chromedriver + 4781621
# 14  chromedriver                        0x000000010b0d5af9 chromedriver + 4639481
# 15  chromedriver                        0x000000010b0f8929 chromedriver + 4782377
# 16  chromedriver                        0x000000010b0c7094 chromedriver + 4579476
# 17  chromedriver                        0x000000010b114a58 chromedriver + 4897368
# 18  chromedriver                        0x000000010b114c53 chromedriver + 4897875
# 19  chromedriver                        0x000000010b12422e chromedriver + 4960814
# 20  libsystem_pthread.dylib             0x00007ff80d004253 _pthread_start + 99
# 21  libsystem_pthread.dylib             0x00007ff80cfffbef thread_start + 15

# %%
file_shadow_host = driver.find_element(By.XPATH, '//*[@id="i2tx2zhp0a1d"]')
file_shadow_root = driver.execute_script("return arguments[0].shadowRoot", file_shadow_host)

# %%
my_drive_button = driver.find_element(By.XPATH, '//*[@id="1"]')
my_drive_button.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[707], line 1
# ----> 1 my_drive_button = driver.find_element(By.XPATH, '//*[@id="1"]')
#       2 my_drive_button.click()
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File /usr/local/Caskroom/miniconda/base/envs/gamma/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="1"]"}
#   (Session info: chrome=129.0.6668.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x000000010b12cd68 chromedriver + 4996456
# 1   chromedriver                        0x000000010b12462a chromedriver + 4961834
# 2   chromedriver                        0x000000010acc7d10 chromedriver + 388368
# 3   chromedriver                        0x000000010ad1430f chromedriver + 701199
# 4   chromedriver                        0x000000010ad143f1 chromedriver + 701425
# 5   chromedriver                        0x000000010ad59464 chromedriver + 984164
# 6   chromedriver                        0x000000010ad389dd chromedriver + 850397
# 7   chromedriver                        0x000000010ad56a00 chromedriver + 973312
# 8   chromedriver                        0x000000010ad38753 chromedriver + 849747
# 9   chromedriver                        0x000000010ad07635 chromedriver + 648757
# 10  chromedriver                        0x000000010ad07e5e chromedriver + 650846
# 11  chromedriver                        0x000000010b0f3050 chromedriver + 4759632
# 12  chromedriver                        0x000000010b0f7f68 chromedriver + 4779880
# 13  chromedriver                        0x000000010b0f8635 chromedriver + 4781621
# 14  chromedriver                        0x000000010b0d5af9 chromedriver + 4639481
# 15  chromedriver                        0x000000010b0f8929 chromedriver + 4782377
# 16  chromedriver                        0x000000010b0c7094 chromedriver + 4579476
# 17  chromedriver                        0x000000010b114a58 chromedriver + 4897368
# 18  chromedriver                        0x000000010b114c53 chromedriver + 4897875
# 19  chromedriver                        0x000000010b12422e chromedriver + 4960814
# 20  libsystem_pthread.dylib             0x00007ff80d004253 _pthread_start + 99
# 21  libsystem_pthread.dylib             0x00007ff80cfffbef thread_start + 15
